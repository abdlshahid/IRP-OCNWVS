# %% [markdown]
# # Directional Fourier Coefficient Prediction Model
#
# This model predicts higher-order directional Fourier coefficients (a3, b3, a4, b4, a5, b5) from input features (S1D, a1, b1, a2, b2) and reconstructs the full 2D spectrum using the complete Fourier series.

# %%
# Directional Fourier Coefficient Model for ERA5 Wave Spectra
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# Load processed data (same as mlp.ipynb)
data_path = "data\processed"
arrays = []

# Load all processed files
for file in os.listdir(data_path):
    print(f"Processing file: {file}")
    full_path = os.path.join(data_path, file)
    print(f"Loading {file}")
    data = np.load(full_path, allow_pickle=False)
    print(f"  Keys: {list(data.keys())}")
    print(f"  X shape: {data['X'].shape}")
    print(f"  y shape: {data['y'].shape}")
    arrays.append(data)

# Combine all samples
total_samples = sum(len(arr['X']) for arr in arrays)
print(f"Total samples: {total_samples}")

# Initialize arrays for combined data
combined_X = []
combined_y = []

for arr in arrays:
    combined_X.append(arr['X'])
    combined_y.append(arr['y'])

# Convert to numpy arrays and extract features
X_combined = np.concatenate(combined_X, axis=0)  # Shape: (samples, 5, 30)
y_combined = np.concatenate(combined_y, axis=0)  # Shape: (samples, 30, 24)

# Extract ALL components from X
S1D = X_combined[:, 0, :]  # 1D spectra: (samples, 30)
a1 = X_combined[:, 1, :]   # Directional moment a1: (samples, 30)  
b1 = X_combined[:, 2, :]   # Directional moment b1: (samples, 30)
a2 = X_combined[:, 3, :]   # Directional moment a2: (samples, 30)
b2 = X_combined[:, 4, :]   # Directional moment b2: (samples, 30)
S2D = y_combined           # 2D spectra: (samples, 30, 24)

print(f"Data shapes:")
print(f"S1D: {S1D.shape}")
print(f"S2D: {S2D.shape}")
print(f"a1: {a1.shape}")
print(f"b1: {b1.shape}")
print(f"a2: {a2.shape}")
print(f"b2: {b2.shape}")

# Check for any NaN values in loaded data
print(f"NaN values in S1D: {np.isnan(S1D).sum()}")
print(f"NaN values in S2D: {np.isnan(S2D).sum()}")
print(f"NaN values in a1: {np.isnan(a1).sum()}")
print(f"NaN values in b1: {np.isnan(b1).sum()}")
print(f"NaN values in a2: {np.isnan(a2).sum()}")
print(f"NaN values in b2: {np.isnan(b2).sum()}")
# Out:
# Processing file: era5_wave_training.npz
# Loading era5_wave_training.npz
#   Keys: ['X', 'y', 'freq_hz', 'direction_deg', 'valid_time']
#   X shape: (9504, 5, 30)
#   y shape: (9504, 30, 24)
# Total samples: 9504
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7420\4245064718.py:2: SyntaxWarning: invalid escape sequence '\p'
#   data_path = "data\processed"
# Data shapes:
# S1D: (9504, 30)
# S2D: (9504, 30, 24)
# a1: (9504, 30)
# b1: (9504, 30)
# a2: (9504, 30)
# b2: (9504, 30)
# NaN values in S1D: 0
# NaN values in S2D: 0
# NaN values in a1: 0
# NaN values in b1: 0
# NaN values in a2: 0
# NaN values in b2: 0

# %%
# Compute target higher-order Fourier coefficients from 2D spectra
print("Computing higher-order Fourier coefficients from 2D spectra...")

def compute_fourier_coefficients(S2D, n_dir=24, max_harmonic=5):
    """Compute Fourier coefficients up to max_harmonic from 2D spectrum"""
    batch_size, n_freq = S2D.shape[0], S2D.shape[1]
    
    # ERA5 directional grid - midpoints: 7.5°, 22.5°, ..., 352.5°
    direction_deg = 7.5 + 15 * np.arange(n_dir)
    theta = np.deg2rad(direction_deg)
    dtheta = 2 * np.pi / n_dir
    
    # Initialize coefficient arrays
    coefficients = {}
    for n in range(1, max_harmonic + 1):
        coefficients[f'a{n}'] = np.zeros((batch_size, n_freq))
        coefficients[f'b{n}'] = np.zeros((batch_size, n_freq))
    
    # Compute 1D spectrum by integrating over directions
    S1D_computed = np.trapezoid(S2D, dx=dtheta, axis=2)
    
    for i in range(batch_size):
        for j in range(n_freq):
            if S1D_computed[i, j] > 1e-15:  # Only process non-zero frequencies
                # Normalized directional distribution
                D = S2D[i, j, :] / S1D_computed[i, j]
                
                # Compute Fourier coefficients for each harmonic
                for n in range(1, max_harmonic + 1):
                    # Fourier integrals
                    a_n = np.trapezoid(D * np.cos(n * theta), dx=dtheta)
                    b_n = np.trapezoid(D * np.sin(n * theta), dx=dtheta)
                    
                    coefficients[f'a{n}'][i, j] = a_n
                    coefficients[f'b{n}'][i, j] = b_n
    
    return coefficients, S1D_computed

# Compute all Fourier coefficients
coefficients, S1D_computed = compute_fourier_coefficients(S2D)

# Extract individual coefficients
a1_computed = coefficients['a1']
b1_computed = coefficients['b1']
a2_computed = coefficients['a2']
b2_computed = coefficients['b2']
a3_target = coefficients['a3']
b3_target = coefficients['b3']
a4_target = coefficients['a4']
b4_target = coefficients['b4']
a5_target = coefficients['a5']
b5_target = coefficients['b5']

print(f"Computed Fourier coefficients:")
print(f"a3_target shape: {a3_target.shape}")
print(f"b3_target shape: {b3_target.shape}")
print(f"a4_target shape: {a4_target.shape}")
print(f"b4_target shape: {b4_target.shape}")
print(f"a5_target shape: {a5_target.shape}")
print(f"b5_target shape: {b5_target.shape}")

# Verify consistency with input data
print(f"\nConsistency check (input vs computed):")
print(f"S1D error: {np.mean(np.abs(S1D - S1D_computed)):.6e}")
print(f"a1 error: {np.mean(np.abs(a1 - a1_computed)):.6e}")
print(f"b1 error: {np.mean(np.abs(b1 - b1_computed)):.6e}")
print(f"a2 error: {np.mean(np.abs(a2 - a2_computed)):.6e}")
print(f"b2 error: {np.mean(np.abs(b2 - b2_computed)):.6e}")
# Out:
# Computing higher-order Fourier coefficients from 2D spectra...
# Computed Fourier coefficients:
# a3_target shape: (9504, 30)
# b3_target shape: (9504, 30)
# a4_target shape: (9504, 30)
# b4_target shape: (9504, 30)
# a5_target shape: (9504, 30)
# b5_target shape: (9504, 30)
#
# Consistency check (input vs computed):
# S1D error: 2.940387e-03
# a1 error: 8.630481e-03
# b1 error: 8.084460e-03
# a2 error: 1.903311e-02
# b2 error: 6.125555e-03

# %%
# Prepare data for training
print("Preparing data for directional coefficient prediction...")

# Model inputs: (batch, freq, channels) = (batch, 30, 5)
# Channels: [S1D, a1, b1, a2, b2]
inputs = np.stack([S1D, a1, b1, a2, b2], axis=2)  # Shape: (batch_size, 30, 5)

# Model targets: (batch, freq, channels) = (batch, 30, 6)
# Channels: [a3, b3, a4, b4, a5, b5]
targets = np.stack([a3_target, b3_target, a4_target, b4_target, a5_target, b5_target], axis=2)

print(f"Input shape: {inputs.shape} (batch, freq=30, input_channels=5)")
print(f"Target shape: {targets.shape} (batch, freq=30, output_channels=6)")
print(f"Input channels: [S1D, a1, b1, a2, b2]")
print(f"Target channels: [a3, b3, a4, b4, a5, b5]")

# Check for NaN values
nan_inputs = np.isnan(inputs).sum()
nan_targets = np.isnan(targets).sum()
print(f"NaN in inputs: {nan_inputs}")
print(f"NaN in targets: {nan_targets}")

if nan_inputs > 0 or nan_targets > 0:
    print("WARNING: NaN values detected! Will clean...")
    # Find rows with any NaN
    input_mask = ~np.isnan(inputs).any(axis=(1,2))
    target_mask = ~np.isnan(targets).any(axis=(1,2))
    valid_mask = input_mask & target_mask
    
    print(f"Valid samples: {valid_mask.sum()}/{len(valid_mask)}")
    
    # Filter out NaN samples
    inputs = inputs[valid_mask]
    targets = targets[valid_mask]
    S2D = S2D[valid_mask]
    print(f"Cleaned input shape: {inputs.shape}")
    print(f"Cleaned target shape: {targets.shape}")

# Basic statistics
print(f"\nData statistics:")
print(f"Input range: [{inputs.min():.6f}, {inputs.max():.6f}]")
print(f"Target range: [{targets.min():.6f}, {targets.max():.6f}]")
print(f"Input mean: {inputs.mean():.6f}, std: {inputs.std():.6f}")
print(f"Target mean: {targets.mean():.6f}, std: {targets.std():.6f}")
# Out:
# Preparing data for directional coefficient prediction...
# Input shape: (9504, 30, 5) (batch, freq=30, input_channels=5)
# Target shape: (9504, 30, 6) (batch, freq=30, output_channels=6)
# Input channels: [S1D, a1, b1, a2, b2]
# Target channels: [a3, b3, a4, b4, a5, b5]
# NaN in inputs: 0
# NaN in targets: 0
#
# Data statistics:
# Input range: [-0.991445, 22.504860]
# Target range: [-1.000000, 1.000000]
# Input mean: -0.121308, std: 0.506509
# Target mean: 0.026248, std: 0.300908

# %%
# Normalize data and create train/val/test splits
print("Normalizing data and creating splits...")

# Normalize inputs per channel (feature-wise normalization)
input_mean = inputs.mean(axis=(0, 1), keepdims=True)  # Mean over batch and frequency
input_std = inputs.std(axis=(0, 1), keepdims=True) + 1e-8  # Std over batch and frequency
inputs_norm = (inputs - input_mean) / input_std

# Normalize targets per channel 
target_mean = targets.mean(axis=(0, 1), keepdims=True)
target_std = targets.std(axis=(0, 1), keepdims=True) + 1e-8
targets_norm = (targets - target_mean) / target_std

# Save normalization parameters
os.makedirs("models", exist_ok=True)
np.savez("models/dir_normalization.npz", 
         input_mean=input_mean, input_std=input_std,
         target_mean=target_mean, target_std=target_std)
print(f"💾 Saved normalization parameters to models/dir_normalization.npz")

print(f"Input normalization:")
print(f"  Mean shape: {input_mean.shape}, Std shape: {input_std.shape}")
print(f"  Normalized range: [{inputs_norm.min():.6f}, {inputs_norm.max():.6f}]")

print(f"Target normalization:")
print(f"  Mean shape: {target_mean.shape}, Std shape: {target_std.shape}")
print(f"  Normalized range: [{targets_norm.min():.6f}, {targets_norm.max():.6f}]")

# Split data chronologically (proper for time-series wave data)
n_samples = len(inputs_norm)
n_train = int(0.7 * n_samples)
n_val = int(0.15 * n_samples)
n_test = n_samples - n_train - n_val

# Chronological order (don't shuffle)
indices = np.arange(n_samples)
train_idx = indices[:n_train]
val_idx = indices[n_train:n_train+n_val]
test_idx = indices[n_train+n_val:]

# Create splits
X_train, y_train = inputs_norm[train_idx], targets_norm[train_idx]
X_val, y_val = inputs_norm[val_idx], targets_norm[val_idx] 
X_test, y_test = inputs_norm[test_idx], targets_norm[test_idx]

# Also split original data for evaluation
S2D_train = S2D[train_idx]
S2D_val = S2D[val_idx]
S2D_test = S2D[test_idx]

print(f"\nData splits:")
print(f"Train: {X_train.shape[0]} samples ({X_train.shape})")
print(f"Val: {X_val.shape[0]} samples ({X_val.shape})")
print(f"Test: {X_test.shape[0]} samples ({X_test.shape})")

# Convert to PyTorch tensors
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

X_train_t = torch.FloatTensor(X_train).to(device)
y_train_t = torch.FloatTensor(y_train).to(device)
X_val_t = torch.FloatTensor(X_val).to(device)
y_val_t = torch.FloatTensor(y_val).to(device)
X_test_t = torch.FloatTensor(X_test).to(device)
# Out:
# Normalizing data and creating splits...
# 💾 Saved normalization parameters to models/dir_normalization.npz
# Input normalization:
#   Mean shape: (1, 1, 5), Std shape: (1, 1, 5)
#   Normalized range: [-2.614872, 46.798307]
# Target normalization:
#   Mean shape: (1, 1, 6), Std shape: (1, 1, 6)
#   Normalized range: [-4.608806, 3.998548]
#
# Data splits:
# Train: 6652 samples ((6652, 30, 5))
# Val: 1425 samples ((1425, 30, 5))
# Test: 1427 samples ((1427, 30, 5))
# Using device: cpu

# %%
# Define the directional coefficient prediction model
class DirectionalCoefficientModel(nn.Module):
    def __init__(self, input_channels=5, output_channels=6, hidden_size=128, num_layers=3, dropout=0.1):
        super(DirectionalCoefficientModel, self).__init__()
        self.input_channels = input_channels
        self.output_channels = output_channels
        
        # Build MLP layers
        layers = []
        
        # Input layer
        layers.append(nn.Linear(input_channels, hidden_size))
        layers.append(nn.ReLU())
        layers.append(nn.BatchNorm1d(hidden_size))
        layers.append(nn.Dropout(dropout))
        
        # Hidden layers
        for _ in range(num_layers - 2):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.ReLU())
            layers.append(nn.BatchNorm1d(hidden_size))
            layers.append(nn.Dropout(dropout))
        
        # Output layer (no activation - regression)
        layers.append(nn.Linear(hidden_size, output_channels))
        
        self.network = nn.ModuleList(layers)
        
        # Initialize weights
        self._init_weights()
    
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
    
    def forward(self, x):
        # x shape: (batch, freq, input_channels)
        batch_size, n_freq, _ = x.shape
        
        # Reshape for processing: (batch * freq, input_channels)
        x = x.reshape(-1, self.input_channels)
        
        # Apply network layers
        for layer in self.network:
            x = layer(x)
        
        # Reshape back: (batch, freq, output_channels)
        x = x.reshape(batch_size, n_freq, self.output_channels)
        
        return x

# %%
# Create model
model = DirectionalCoefficientModel(
    input_channels=5,   # [S1D, a1, b1, a2, b2]
    output_channels=6,  # [a3, b3, a4, b4, a5, b5]
    hidden_size=256,
    num_layers=4,
    dropout=0.1
).to(device)

print(f"Directional Coefficient Model created:")
print(f"Input channels: 5 [S1D, a1, b1, a2, b2]")
print(f"Output channels: 6 [a3, b3, a4, b4, a5, b5]")
print(f"Hidden size: 256")
print(f"Number of parameters: {sum(p.numel() for p in model.parameters()):,}")

# Test forward pass
test_batch = X_train_t[:4]
with torch.no_grad():
    test_output = model(test_batch)
    print(f"Test input shape: {test_batch.shape}")
    print(f"Test output shape: {test_output.shape}")
    print(f"Test output range: [{test_output.min().item():.6f}, {test_output.max().item():.6f}]")
    print(f"Test output has NaN: {torch.isnan(test_output).any().item()}")

print("✅ Model architecture defined successfully")
# Out:
# Directional Coefficient Model created:
# Input channels: 5 [S1D, a1, b1, a2, b2]
# Output channels: 6 [a3, b3, a4, b4, a5, b5]
# Hidden size: 256
# Number of parameters: 136,198
# Test input shape: torch.Size([4, 30, 5])
# Test output shape: torch.Size([4, 30, 6])
# Test output range: [-7.350005, 5.914580]
# Test output has NaN: False
# ✅ Model architecture defined successfully

# %%
# Define reconstruction and loss functions
def reconstruct_2d_spectrum_fourier(S1D, a1, b1, a2, b2, a3, b3, a4, b4, a5, b5, n_dir=24):
    """Reconstruct 2D spectrum using complete Fourier series representation"""
    batch_size, n_freq = S1D.shape
    
    # ERA5 directional grid - midpoints: 7.5°, 22.5°, ..., 352.5°
    direction_deg = 7.5 + 15 * torch.arange(n_dir, device=S1D.device)
    theta = torch.deg2rad(direction_deg)[None, None, :]  # Shape: (1, 1, n_dir)
    
    # Compute directional distribution using Fourier series
    # D(θ) = 1/(2π) * (1 + 2*a1*cos(θ) + 2*b1*sin(θ) + 2*a2*cos(2θ) + 2*b2*sin(2θ) + ...)
    D = torch.ones(batch_size, n_freq, n_dir, device=S1D.device) / (2 * torch.pi)
    
    # Add each harmonic contribution
    D += (2 / (2 * torch.pi)) * (
        a1.unsqueeze(-1) * torch.cos(theta) +
        b1.unsqueeze(-1) * torch.sin(theta) +
        a2.unsqueeze(-1) * torch.cos(2 * theta) +
        b2.unsqueeze(-1) * torch.sin(2 * theta) +
        a3.unsqueeze(-1) * torch.cos(3 * theta) +
        b3.unsqueeze(-1) * torch.sin(3 * theta) +
        a4.unsqueeze(-1) * torch.cos(4 * theta) +
        b4.unsqueeze(-1) * torch.sin(4 * theta) +
        a5.unsqueeze(-1) * torch.cos(5 * theta) +
        b5.unsqueeze(-1) * torch.sin(5 * theta)
    )
    
    # Ensure non-negative directional distribution
    D = torch.clamp(D, min=0.0)
    
    # Normalize D to integrate to 1 over directions
    dtheta = 2 * torch.pi / n_dir
    D_sum = torch.sum(D, dim=2, keepdim=True) * dtheta
    D = D / torch.clamp(D_sum, min=1e-10)
    
    # Reconstruct 2D spectrum: S(f,θ) = S(f) * D(θ)
    S2D_reconstructed = S1D.unsqueeze(-1) * D
    
    return S2D_reconstructed

def fourier_loss(pred_coeffs, input_features, target_2d, alpha_smooth=0.01):
    """Loss function for Fourier coefficient prediction"""
    # Extract input features
    S1D = input_features[:, :, 0]  # Shape: (batch, freq)
    a1 = input_features[:, :, 1]
    b1 = input_features[:, :, 2]
    a2 = input_features[:, :, 3]
    b2 = input_features[:, :, 4]
    
    # Extract predicted coefficients
    a3 = pred_coeffs[:, :, 0]
    b3 = pred_coeffs[:, :, 1]
    a4 = pred_coeffs[:, :, 2]
    b4 = pred_coeffs[:, :, 3]
    a5 = pred_coeffs[:, :, 4]
    b5 = pred_coeffs[:, :, 5]
    
    # Reconstruct 2D spectrum using Fourier series
    S2D_pred = reconstruct_2d_spectrum_fourier(
        S1D, a1, b1, a2, b2, a3, b3, a4, b4, a5, b5
    )
    
    # Primary loss: MSE between reconstructed and target 2D spectrum
    mse_loss = torch.mean((S2D_pred - target_2d)**2)
    
    # Optional: Smoothness regularization on predicted coefficients
    smooth_loss = torch.mean(
        (a3[:, 1:] - a3[:, :-1])**2 + (b3[:, 1:] - b3[:, :-1])**2 +
        (a4[:, 1:] - a4[:, :-1])**2 + (b4[:, 1:] - b4[:, :-1])**2 +
        (a5[:, 1:] - a5[:, :-1])**2 + (b5[:, 1:] - b5[:, :-1])**2
    )
    
    total_loss = mse_loss #+ alpha_smooth * smooth_loss
    
    return total_loss, mse_loss, smooth_loss, S2D_pred

# %%
# Test loss function
print("Testing loss function...")
with torch.no_grad():
    # Create test data
    test_pred = model(X_train_t[:4])
    test_input = X_train_t[:4]
    test_target = torch.FloatTensor(S2D_train[:4]).to(device)
    
    # Test loss computation
    total_loss, mse_loss, smooth_loss, S2D_pred = fourier_loss(
        test_pred, test_input, test_target
    )
    
    print(f"Test losses:")
    print(f"  Total: {total_loss.item():.6f}")
    print(f"  MSE: {mse_loss.item():.6f}")
    print(f"  Smooth: {smooth_loss.item():.6f}")
    print(f"  Reconstructed shape: {S2D_pred.shape}")
    print(f"  Reconstructed range: [{S2D_pred.min().item():.6f}, {S2D_pred.max().item():.6f}]")
    
    # Check for NaN
    if torch.isnan(total_loss):
        print("WARNING: NaN in loss function!")
    else:
        print("✅ Loss function working correctly")

print("Loss functions defined successfully")
# Out:
# Testing loss function...
# Test losses:
#   Total: 0.006611
#   MSE: 0.006611
#   Smooth: 16.491074
#   Reconstructed shape: torch.Size([4, 30, 24])
#   Reconstructed range: [-0.339740, 0.207109]
# ✅ Loss function working correctly
# Loss functions defined successfully

# %%
# Training setup
print("Setting up training...")

# Training hyperparameters
learning_rate = 1e-4
batch_size = 32
num_epochs = 50
weight_decay = 1e-5

# Prepare target 2D spectra as tensors
S2D_train_t = torch.FloatTensor(S2D_train).to(device)
S2D_val_t = torch.FloatTensor(S2D_val).to(device)

# Create data loaders
train_dataset = TensorDataset(X_train_t, y_train_t, S2D_train_t)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = TensorDataset(X_val_t, y_val_t, S2D_val_t)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Optimizer and scheduler
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.7, patience=5)

print(f"Training configuration:")
print(f"  Learning rate: {learning_rate}")
print(f"  Batch size: {batch_size}")
print(f"  Number of epochs: {num_epochs}")
print(f"  Weight decay: {weight_decay}")
print(f"  Train batches: {len(train_loader)}")
print(f"  Val batches: {len(val_loader)}")

# Training history
train_losses = []
val_losses = []  
best_val_loss = float('inf')

print("Ready to start directional coefficient training")
# Out:
# Setting up training...
# Training configuration:
#   Learning rate: 0.0001
#   Batch size: 32
#   Number of epochs: 50
#   Weight decay: 1e-05
#   Train batches: 208
#   Val batches: 45
# Ready to start directional coefficient training

# %%
# Training loop
model_path = "models/dir_model.pth"

print("Starting directional coefficient training...")

for epoch in range(num_epochs):
    # Training phase
    model.train()
    epoch_train_loss = 0.0
    train_batches = 0
    
    for batch_idx, (batch_x, batch_y, batch_target_2d) in enumerate(train_loader):
        optimizer.zero_grad()
        
        # Forward pass - predict higher-order coefficients
        pred_coeffs = model(batch_x)
        
        # Compute loss using Fourier reconstruction
        total_loss, mse_loss, smooth_loss, _ = fourier_loss(
            pred_coeffs, batch_x, batch_target_2d
        )
        
        # Check for NaN
        if torch.isnan(total_loss):
            print(f"NaN loss detected at epoch {epoch+1}, batch {batch_idx+1}")
            break
        
        # Backward pass
        total_loss.backward()
        
        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        
        epoch_train_loss += total_loss.item()
        train_batches += 1
        
        # Print progress every 50 batches
        if (batch_idx + 1) % 50 == 0:
            print(f"  Batch {batch_idx+1}/{len(train_loader)}")
            print(f"    Total: {total_loss.item():.6f}, MSE: {mse_loss.item():.6f}, Smooth: {smooth_loss.item():.6f}")
    
    # Validation phase
    model.eval()
    epoch_val_loss = 0.0
    val_batches = 0
    
    with torch.no_grad():
        for batch_x, batch_y, batch_target_2d in val_loader:
            pred_coeffs = model(batch_x)
            total_loss, _, _, _ = fourier_loss(
                pred_coeffs, batch_x, batch_target_2d
            )
            
            if not torch.isnan(total_loss):
                epoch_val_loss += total_loss.item()
                val_batches += 1
    
    # Average losses
    avg_train_loss = epoch_train_loss / max(train_batches, 1)
    avg_val_loss = epoch_val_loss / max(val_batches, 1)
    
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
    
    # Print epoch summary
    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"  Train Loss: {avg_train_loss:.6f}")
    print(f"  Val Loss: {avg_val_loss:.6f}")
    print(f"  Learning Rate: {optimizer.param_groups[0]['lr']:.2e}")
    
    # Learning rate scheduling
    scheduler.step(avg_val_loss)
    
    # Save best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), model_path)
        print(f"  ✅ New best model saved (val_loss: {best_val_loss:.6f})")
    
    print("-" * 50)

print("Training completed!")
print(f"Best validation loss: {best_val_loss:.6f}")
# Out:
# Starting directional coefficient training...
#   Batch 50/208
#     Total: 0.020704, MSE: 0.020704, Smooth: 13.955566
#   Batch 100/208
#     Total: 0.038025, MSE: 0.038025, Smooth: 12.281389
#   Batch 150/208
#     Total: 0.018559, MSE: 0.018559, Smooth: 12.593530
#   Batch 200/208
#     Total: 0.013290, MSE: 0.013290, Smooth: 12.485514
# Epoch 1/50
#   Train Loss: 0.052084
#   Val Loss: 0.029553
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.029553)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.007720, MSE: 0.007720, Smooth: 12.663983
#   Batch 100/208
#     Total: 0.009178, MSE: 0.009178, Smooth: 12.580090
#   Batch 150/208
#     Total: 0.009107, MSE: 0.009107, Smooth: 11.911740
#   Batch 200/208
#     Total: 0.189768, MSE: 0.189768, Smooth: 11.725054
# Epoch 2/50
#   Train Loss: 0.047844
#   Val Loss: 0.024755
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.024755)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009272, MSE: 0.009272, Smooth: 11.161315
#   Batch 100/208
#     Total: 0.011913, MSE: 0.011913, Smooth: 11.033170
#   Batch 150/208
#     Total: 0.010806, MSE: 0.010806, Smooth: 10.414639
#   Batch 200/208
#     Total: 0.023270, MSE: 0.023270, Smooth: 10.260530
# Epoch 3/50
#   Train Loss: 0.045970
#   Val Loss: 0.023371
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.023371)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.012662, MSE: 0.012662, Smooth: 10.603765
#   Batch 100/208
#     Total: 0.053261, MSE: 0.053261, Smooth: 11.224799
#   Batch 150/208
#     Total: 0.220044, MSE: 0.220044, Smooth: 10.441815
#   Batch 200/208
#     Total: 0.022963, MSE: 0.022963, Smooth: 10.419658
# Epoch 4/50
#   Train Loss: 0.043521
#   Val Loss: 0.022508
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.022508)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.005466, MSE: 0.005466, Smooth: 9.621859
#   Batch 100/208
#     Total: 0.016406, MSE: 0.016406, Smooth: 9.781455
#   Batch 150/208
#     Total: 0.005247, MSE: 0.005247, Smooth: 9.173535
#   Batch 200/208
#     Total: 0.009402, MSE: 0.009402, Smooth: 9.547705
# Epoch 5/50
#   Train Loss: 0.042671
#   Val Loss: 0.019243
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.019243)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009647, MSE: 0.009647, Smooth: 9.258103
#   Batch 100/208
#     Total: 0.054231, MSE: 0.054231, Smooth: 9.252203
#   Batch 150/208
#     Total: 0.017995, MSE: 0.017995, Smooth: 9.022922
#   Batch 200/208
#     Total: 0.013449, MSE: 0.013449, Smooth: 8.410824
# Epoch 6/50
#   Train Loss: 0.038902
#   Val Loss: 0.017845
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.017845)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.012844, MSE: 0.012844, Smooth: 8.314280
#   Batch 100/208
#     Total: 0.009057, MSE: 0.009057, Smooth: 7.945278
#   Batch 150/208
#     Total: 0.118134, MSE: 0.118134, Smooth: 8.019311
#   Batch 200/208
#     Total: 0.013566, MSE: 0.013566, Smooth: 8.128153
# Epoch 7/50
#   Train Loss: 0.037814
#   Val Loss: 0.016084
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.016084)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.024422, MSE: 0.024422, Smooth: 7.732606
#   Batch 100/208
#     Total: 0.014314, MSE: 0.014314, Smooth: 7.124060
#   Batch 150/208
#     Total: 0.004968, MSE: 0.004968, Smooth: 6.675755
#   Batch 200/208
#     Total: 0.009112, MSE: 0.009112, Smooth: 7.106390
# Epoch 8/50
#   Train Loss: 0.035756
#   Val Loss: 0.015145
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.015145)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.013553, MSE: 0.013553, Smooth: 6.949480
#   Batch 100/208
#     Total: 0.011624, MSE: 0.011624, Smooth: 7.101516
#   Batch 150/208
#     Total: 0.027733, MSE: 0.027733, Smooth: 7.132498
#   Batch 200/208
#     Total: 0.014681, MSE: 0.014681, Smooth: 7.353631
# Epoch 9/50
#   Train Loss: 0.034195
#   Val Loss: 0.014884
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.014884)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009155, MSE: 0.009155, Smooth: 6.843192
#   Batch 100/208
#     Total: 0.006415, MSE: 0.006415, Smooth: 7.082485
#   Batch 150/208
#     Total: 0.007628, MSE: 0.007628, Smooth: 6.584436
#   Batch 200/208
#     Total: 0.011665, MSE: 0.011665, Smooth: 6.430081
# Epoch 10/50
#   Train Loss: 0.030486
#   Val Loss: 0.014630
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.014630)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.007539, MSE: 0.007539, Smooth: 6.157799
#   Batch 100/208
#     Total: 0.007209, MSE: 0.007209, Smooth: 6.249491
#   Batch 150/208
#     Total: 0.006562, MSE: 0.006562, Smooth: 6.240943
#   Batch 200/208
#     Total: 0.010668, MSE: 0.010668, Smooth: 6.016052
# Epoch 11/50
#   Train Loss: 0.028455
#   Val Loss: 0.014393
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.014393)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.014450, MSE: 0.014450, Smooth: 6.261246
#   Batch 100/208
#     Total: 0.013431, MSE: 0.013431, Smooth: 6.070140
#   Batch 150/208
#     Total: 0.013633, MSE: 0.013633, Smooth: 5.979411
#   Batch 200/208
#     Total: 0.199230, MSE: 0.199230, Smooth: 6.506379
# Epoch 12/50
#   Train Loss: 0.027250
#   Val Loss: 0.013493
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.013493)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.010625, MSE: 0.010625, Smooth: 5.792644
#   Batch 100/208
#     Total: 0.010319, MSE: 0.010319, Smooth: 5.814504
#   Batch 150/208
#     Total: 0.010286, MSE: 0.010286, Smooth: 6.021411
#   Batch 200/208
#     Total: 0.005241, MSE: 0.005241, Smooth: 5.839930
# Epoch 13/50
#   Train Loss: 0.026055
#   Val Loss: 0.013338
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.013338)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.006598, MSE: 0.006598, Smooth: 5.795415
#   Batch 100/208
#     Total: 0.072769, MSE: 0.072769, Smooth: 5.683663
#   Batch 150/208
#     Total: 0.007310, MSE: 0.007310, Smooth: 5.546821
#   Batch 200/208
#     Total: 0.014298, MSE: 0.014298, Smooth: 5.427213
# Epoch 14/50
#   Train Loss: 0.025084
#   Val Loss: 0.013195
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.013195)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.010470, MSE: 0.010470, Smooth: 5.713537
#   Batch 100/208
#     Total: 0.144839, MSE: 0.144839, Smooth: 5.458861
#   Batch 150/208
#     Total: 0.024380, MSE: 0.024380, Smooth: 5.445385
#   Batch 200/208
#     Total: 0.010766, MSE: 0.010766, Smooth: 5.310874
# Epoch 15/50
#   Train Loss: 0.024185
#   Val Loss: 0.012746
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.012746)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.008762, MSE: 0.008762, Smooth: 5.208718
#   Batch 100/208
#     Total: 0.007730, MSE: 0.007730, Smooth: 5.224228
#   Batch 150/208
#     Total: 0.012023, MSE: 0.012023, Smooth: 5.542777
#   Batch 200/208
#     Total: 0.006258, MSE: 0.006258, Smooth: 5.125164
# Epoch 16/50
#   Train Loss: 0.023285
#   Val Loss: 0.013175
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.007819, MSE: 0.007819, Smooth: 5.060083
#   Batch 100/208
#     Total: 0.007796, MSE: 0.007796, Smooth: 5.223161
#   Batch 150/208
#     Total: 0.008959, MSE: 0.008959, Smooth: 5.289150
#   Batch 200/208
#     Total: 0.078869, MSE: 0.078869, Smooth: 4.906772
# Epoch 17/50
#   Train Loss: 0.022500
#   Val Loss: 0.012744
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.012744)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009220, MSE: 0.009220, Smooth: 4.978764
#   Batch 100/208
#     Total: 0.012288, MSE: 0.012288, Smooth: 4.874548
#   Batch 150/208
#     Total: 0.018838, MSE: 0.018838, Smooth: 4.887690
#   Batch 200/208
#     Total: 0.016991, MSE: 0.016991, Smooth: 4.971752
# Epoch 18/50
#   Train Loss: 0.022373
#   Val Loss: 0.012519
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.012519)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.007950, MSE: 0.007950, Smooth: 5.122797
#   Batch 100/208
#     Total: 0.012639, MSE: 0.012639, Smooth: 4.961282
#   Batch 150/208
#     Total: 0.012723, MSE: 0.012723, Smooth: 5.115306
#   Batch 200/208
#     Total: 0.011134, MSE: 0.011134, Smooth: 5.018109
# Epoch 19/50
#   Train Loss: 0.022072
#   Val Loss: 0.012735
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.016554, MSE: 0.016554, Smooth: 4.750596
#   Batch 100/208
#     Total: 0.004569, MSE: 0.004569, Smooth: 4.331081
#   Batch 150/208
#     Total: 0.008263, MSE: 0.008263, Smooth: 4.728342
#   Batch 200/208
#     Total: 0.007476, MSE: 0.007476, Smooth: 5.015377
# Epoch 20/50
#   Train Loss: 0.021250
#   Val Loss: 0.012333
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.012333)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.005410, MSE: 0.005410, Smooth: 4.937384
#   Batch 100/208
#     Total: 0.149950, MSE: 0.149950, Smooth: 5.090287
#   Batch 150/208
#     Total: 0.009772, MSE: 0.009772, Smooth: 4.847062
#   Batch 200/208
#     Total: 0.007576, MSE: 0.007576, Smooth: 4.832284
# Epoch 21/50
#   Train Loss: 0.021598
#   Val Loss: 0.012391
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.018232, MSE: 0.018232, Smooth: 4.672856
#   Batch 100/208
#     Total: 0.012517, MSE: 0.012517, Smooth: 4.854823
#   Batch 150/208
#     Total: 0.009834, MSE: 0.009834, Smooth: 4.908787
#   Batch 200/208
#     Total: 0.005057, MSE: 0.005057, Smooth: 4.523342
# Epoch 22/50
#   Train Loss: 0.020883
#   Val Loss: 0.012397
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.011115, MSE: 0.011115, Smooth: 4.709882
#   Batch 100/208
#     Total: 0.015702, MSE: 0.015702, Smooth: 4.708789
#   Batch 150/208
#     Total: 0.009297, MSE: 0.009297, Smooth: 4.405611
#   Batch 200/208
#     Total: 0.006171, MSE: 0.006171, Smooth: 4.712451
# Epoch 23/50
#   Train Loss: 0.020316
#   Val Loss: 0.012166
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.012166)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.008130, MSE: 0.008130, Smooth: 4.327273
#   Batch 100/208
#     Total: 0.098745, MSE: 0.098745, Smooth: 4.707966
#   Batch 150/208
#     Total: 0.149328, MSE: 0.149328, Smooth: 4.781768
#   Batch 200/208
#     Total: 0.010333, MSE: 0.010333, Smooth: 4.429626
# Epoch 24/50
#   Train Loss: 0.020453
#   Val Loss: 0.012082
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.012082)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.005989, MSE: 0.005989, Smooth: 4.535821
#   Batch 100/208
#     Total: 0.011823, MSE: 0.011823, Smooth: 4.391191
#   Batch 150/208
#     Total: 0.007684, MSE: 0.007684, Smooth: 4.403361
#   Batch 200/208
#     Total: 0.011461, MSE: 0.011461, Smooth: 4.479242
# Epoch 25/50
#   Train Loss: 0.020312
#   Val Loss: 0.012172
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.005811, MSE: 0.005811, Smooth: 4.406810
#   Batch 100/208
#     Total: 0.019261, MSE: 0.019261, Smooth: 4.661536
#   Batch 150/208
#     Total: 0.011455, MSE: 0.011455, Smooth: 4.142934
#   Batch 200/208
#     Total: 0.009024, MSE: 0.009024, Smooth: 4.732141
# Epoch 26/50
#   Train Loss: 0.020899
#   Val Loss: 0.012316
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.007973, MSE: 0.007973, Smooth: 4.158736
#   Batch 100/208
#     Total: 0.087299, MSE: 0.087299, Smooth: 4.654926
#   Batch 150/208
#     Total: 0.005262, MSE: 0.005262, Smooth: 4.181723
#   Batch 200/208
#     Total: 0.005160, MSE: 0.005160, Smooth: 4.068058
# Epoch 27/50
#   Train Loss: 0.019915
#   Val Loss: 0.012349
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.008426, MSE: 0.008426, Smooth: 4.640491
#   Batch 100/208
#     Total: 0.006551, MSE: 0.006551, Smooth: 4.413906
#   Batch 150/208
#     Total: 0.008123, MSE: 0.008123, Smooth: 4.417214
#   Batch 200/208
#     Total: 0.004873, MSE: 0.004873, Smooth: 4.043393
# Epoch 28/50
#   Train Loss: 0.019800
#   Val Loss: 0.012005
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.012005)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009981, MSE: 0.009981, Smooth: 4.324034
#   Batch 100/208
#     Total: 0.008115, MSE: 0.008115, Smooth: 4.335841
#   Batch 150/208
#     Total: 0.005955, MSE: 0.005955, Smooth: 4.248426
#   Batch 200/208
#     Total: 0.010146, MSE: 0.010146, Smooth: 4.327755
# Epoch 29/50
#   Train Loss: 0.019397
#   Val Loss: 0.012008
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009005, MSE: 0.009005, Smooth: 4.569406
#   Batch 100/208
#     Total: 0.009833, MSE: 0.009833, Smooth: 4.288244
#   Batch 150/208
#     Total: 0.010257, MSE: 0.010257, Smooth: 4.061390
#   Batch 200/208
#     Total: 0.007579, MSE: 0.007579, Smooth: 4.469272
# Epoch 30/50
#   Train Loss: 0.019588
#   Val Loss: 0.011958
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.011958)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.006240, MSE: 0.006240, Smooth: 4.016977
#   Batch 100/208
#     Total: 0.005455, MSE: 0.005455, Smooth: 3.968816
#   Batch 150/208
#     Total: 0.016594, MSE: 0.016594, Smooth: 4.462260
#   Batch 200/208
#     Total: 0.020159, MSE: 0.020159, Smooth: 4.021770
# Epoch 31/50
#   Train Loss: 0.019359
#   Val Loss: 0.011967
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.005950, MSE: 0.005950, Smooth: 4.110977
#   Batch 100/208
#     Total: 0.012187, MSE: 0.012187, Smooth: 4.074556
#   Batch 150/208
#     Total: 0.006492, MSE: 0.006492, Smooth: 3.800622
#   Batch 200/208
#     Total: 0.007337, MSE: 0.007337, Smooth: 4.300446
# Epoch 32/50
#   Train Loss: 0.019290
#   Val Loss: 0.011991
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009804, MSE: 0.009804, Smooth: 3.872030
#   Batch 100/208
#     Total: 0.008203, MSE: 0.008203, Smooth: 4.114013
#   Batch 150/208
#     Total: 0.011356, MSE: 0.011356, Smooth: 3.790866
#   Batch 200/208
#     Total: 0.006277, MSE: 0.006277, Smooth: 4.050297
# Epoch 33/50
#   Train Loss: 0.019328
#   Val Loss: 0.011848
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.011848)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.007219, MSE: 0.007219, Smooth: 3.957331
#   Batch 100/208
#     Total: 0.007097, MSE: 0.007097, Smooth: 3.728611
#   Batch 150/208
#     Total: 0.007267, MSE: 0.007267, Smooth: 3.966964
#   Batch 200/208
#     Total: 0.130030, MSE: 0.130030, Smooth: 3.869723
# Epoch 34/50
#   Train Loss: 0.018903
#   Val Loss: 0.011876
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.011742, MSE: 0.011742, Smooth: 3.909889
#   Batch 100/208
#     Total: 0.008462, MSE: 0.008462, Smooth: 3.558673
#   Batch 150/208
#     Total: 0.010899, MSE: 0.010899, Smooth: 3.915398
#   Batch 200/208
#     Total: 0.010931, MSE: 0.010931, Smooth: 4.112782
# Epoch 35/50
#   Train Loss: 0.018940
#   Val Loss: 0.012086
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.009093, MSE: 0.009093, Smooth: 4.185745
#   Batch 100/208
#     Total: 0.116276, MSE: 0.116276, Smooth: 4.082526
#   Batch 150/208
#     Total: 0.122477, MSE: 0.122477, Smooth: 3.848732
#   Batch 200/208
#     Total: 0.007768, MSE: 0.007768, Smooth: 4.203992
# Epoch 36/50
#   Train Loss: 0.018916
#   Val Loss: 0.012025
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.006626, MSE: 0.006626, Smooth: 3.829546
#   Batch 100/208
#     Total: 0.015390, MSE: 0.015390, Smooth: 3.703570
#   Batch 150/208
#     Total: 0.143770, MSE: 0.143770, Smooth: 3.883146
#   Batch 200/208
#     Total: 0.011146, MSE: 0.011146, Smooth: 3.744427
# Epoch 37/50
#   Train Loss: 0.018665
#   Val Loss: 0.011840
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.011840)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.006776, MSE: 0.006776, Smooth: 3.782277
#   Batch 100/208
#     Total: 0.005125, MSE: 0.005125, Smooth: 3.909368
#   Batch 150/208
#     Total: 0.010046, MSE: 0.010046, Smooth: 3.933478
#   Batch 200/208
#     Total: 0.013711, MSE: 0.013711, Smooth: 3.901100
# Epoch 38/50
#   Train Loss: 0.018703
#   Val Loss: 0.012005
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.015943, MSE: 0.015943, Smooth: 3.974423
#   Batch 100/208
#     Total: 0.006356, MSE: 0.006356, Smooth: 3.659727
#   Batch 150/208
#     Total: 0.098657, MSE: 0.098657, Smooth: 3.796065
#   Batch 200/208
#     Total: 0.007923, MSE: 0.007923, Smooth: 4.163360
# Epoch 39/50
#   Train Loss: 0.018622
#   Val Loss: 0.011682
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.011682)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.004776, MSE: 0.004776, Smooth: 3.860417
#   Batch 100/208
#     Total: 0.008754, MSE: 0.008754, Smooth: 3.998901
#   Batch 150/208
#     Total: 0.010559, MSE: 0.010559, Smooth: 3.881851
#   Batch 200/208
#     Total: 0.008533, MSE: 0.008533, Smooth: 3.696861
# Epoch 40/50
#   Train Loss: 0.018401
#   Val Loss: 0.012047
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.021261, MSE: 0.021261, Smooth: 4.161021
#   Batch 100/208
#     Total: 0.010123, MSE: 0.010123, Smooth: 3.595623
#   Batch 150/208
#     Total: 0.008371, MSE: 0.008371, Smooth: 3.744227
#   Batch 200/208
#     Total: 0.006008, MSE: 0.006008, Smooth: 3.599416
# Epoch 41/50
#   Train Loss: 0.018556
#   Val Loss: 0.011579
#   Learning Rate: 1.00e-04
#   ✅ New best model saved (val_loss: 0.011579)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.008354, MSE: 0.008354, Smooth: 3.375999
#   Batch 100/208
#     Total: 0.007986, MSE: 0.007986, Smooth: 3.812287
#   Batch 150/208
#     Total: 0.102369, MSE: 0.102369, Smooth: 3.658954
#   Batch 200/208
#     Total: 0.004344, MSE: 0.004344, Smooth: 3.666251
# Epoch 42/50
#   Train Loss: 0.018496
#   Val Loss: 0.011652
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.004342, MSE: 0.004342, Smooth: 3.636199
#   Batch 100/208
#     Total: 0.011378, MSE: 0.011378, Smooth: 3.780242
#   Batch 150/208
#     Total: 0.009396, MSE: 0.009396, Smooth: 3.658631
#   Batch 200/208
#     Total: 0.006733, MSE: 0.006733, Smooth: 3.453418
# Epoch 43/50
#   Train Loss: 0.018071
#   Val Loss: 0.011634
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.010869, MSE: 0.010869, Smooth: 3.501219
#   Batch 100/208
#     Total: 0.005526, MSE: 0.005526, Smooth: 3.657433
#   Batch 150/208
#     Total: 0.005856, MSE: 0.005856, Smooth: 3.927685
#   Batch 200/208
#     Total: 0.008419, MSE: 0.008419, Smooth: 4.037960
# Epoch 44/50
#   Train Loss: 0.018140
#   Val Loss: 0.011873
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.141413, MSE: 0.141413, Smooth: 3.362157
#   Batch 100/208
#     Total: 0.008720, MSE: 0.008720, Smooth: 3.610682
#   Batch 150/208
#     Total: 0.007236, MSE: 0.007236, Smooth: 3.439354
#   Batch 200/208
#     Total: 0.006292, MSE: 0.006292, Smooth: 3.715024
# Epoch 45/50
#   Train Loss: 0.018109
#   Val Loss: 0.011761
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.005572, MSE: 0.005572, Smooth: 3.225968
#   Batch 100/208
#     Total: 0.006251, MSE: 0.006251, Smooth: 3.497209
#   Batch 150/208
#     Total: 0.009559, MSE: 0.009559, Smooth: 3.417949
#   Batch 200/208
#     Total: 0.007914, MSE: 0.007914, Smooth: 3.382554
# Epoch 46/50
#   Train Loss: 0.018142
#   Val Loss: 0.011617
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.006572, MSE: 0.006572, Smooth: 3.396605
#   Batch 100/208
#     Total: 0.007174, MSE: 0.007174, Smooth: 3.457866
#   Batch 150/208
#     Total: 0.010189, MSE: 0.010189, Smooth: 3.391746
#   Batch 200/208
#     Total: 0.009046, MSE: 0.009046, Smooth: 3.242847
# Epoch 47/50
#   Train Loss: 0.017911
#   Val Loss: 0.011705
#   Learning Rate: 1.00e-04
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.117839, MSE: 0.117839, Smooth: 3.137725
#   Batch 100/208
#     Total: 0.013674, MSE: 0.013674, Smooth: 3.648426
#   Batch 150/208
#     Total: 0.009107, MSE: 0.009107, Smooth: 3.138214
#   Batch 200/208
#     Total: 0.004821, MSE: 0.004821, Smooth: 3.113170
# Epoch 48/50
#   Train Loss: 0.017977
#   Val Loss: 0.011663
#   Learning Rate: 7.00e-05
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.011677, MSE: 0.011677, Smooth: 3.367442
#   Batch 100/208
#     Total: 0.011071, MSE: 0.011071, Smooth: 3.250828
#   Batch 150/208
#     Total: 0.123334, MSE: 0.123334, Smooth: 3.195902
#   Batch 200/208
#     Total: 0.008903, MSE: 0.008903, Smooth: 3.185957
# Epoch 49/50
#   Train Loss: 0.017848
#   Val Loss: 0.011529
#   Learning Rate: 7.00e-05
#   ✅ New best model saved (val_loss: 0.011529)
# --------------------------------------------------
#   Batch 50/208
#     Total: 0.007080, MSE: 0.007080, Smooth: 3.084201
#   Batch 100/208
#     Total: 0.005663, MSE: 0.005663, Smooth: 3.216332
#   Batch 150/208
#     Total: 0.012843, MSE: 0.012843, Smooth: 3.375724
#   Batch 200/208
#     Total: 0.004066, MSE: 0.004066, Smooth: 3.312651
# Epoch 50/50
#   Train Loss: 0.017726
#   Val Loss: 0.011541
#   Learning Rate: 7.00e-05
# --------------------------------------------------
# Training completed!
# Best validation loss: 0.011529

# %%
# Model evaluation
print("Evaluating directional coefficient model...")

# Load best model
model.load_state_dict(torch.load(model_path))
model.eval()

# Make predictions on test set
with torch.no_grad():
    test_pred_coeffs = model(X_test_t)
    
    # Denormalize predicted coefficients
    test_pred_coeffs_denorm = test_pred_coeffs * torch.FloatTensor(target_std).to(device) + torch.FloatTensor(target_mean).to(device)
    
    # Denormalize input features for reconstruction
    X_test_denorm = X_test_t * torch.FloatTensor(input_std).to(device) + torch.FloatTensor(input_mean).to(device)
    
    # Extract denormalized input features
    S1D_test = X_test_denorm[:, :, 0]
    a1_test = X_test_denorm[:, :, 1]
    b1_test = X_test_denorm[:, :, 2]
    a2_test = X_test_denorm[:, :, 3]
    b2_test = X_test_denorm[:, :, 4]
    
    # Extract predicted coefficients
    a3_test = test_pred_coeffs_denorm[:, :, 0]
    b3_test = test_pred_coeffs_denorm[:, :, 1]
    a4_test = test_pred_coeffs_denorm[:, :, 2]
    b4_test = test_pred_coeffs_denorm[:, :, 3]
    a5_test = test_pred_coeffs_denorm[:, :, 4]
    b5_test = test_pred_coeffs_denorm[:, :, 5]
    
    # Reconstruct 2D spectrum using complete Fourier series
    S2D_reconstructed = reconstruct_2d_spectrum_fourier(
        S1D_test, a1_test, b1_test, a2_test, b2_test,
        a3_test, b3_test, a4_test, b4_test, a5_test, b5_test
    )

# Convert to numpy for evaluation
S2D_reconstructed_np = S2D_reconstructed.cpu().numpy()
S2D_test_target = S2D_test

# Compute evaluation metrics
def compute_relative_error(pred, target):
    """Compute relative error with proper handling of small values"""
    epsilon = 1e-15
    target_safe = np.maximum(target, epsilon)
    rel_error = np.abs(pred - target) / target_safe
    weights = target / (np.sum(target, axis=(1,2), keepdims=True) + epsilon)
    weighted_error = np.sum(weights * rel_error, axis=(1,2))
    return np.mean(weighted_error)

# Compute errors
dir_error = compute_relative_error(S2D_reconstructed_np, S2D_test_target)

# L2 norm error
n_time = len(S2D_test_target)
norm_true = np.linalg.norm(S2D_test_target.reshape(n_time, -1), axis=1)
norm_diff = np.linalg.norm((S2D_reconstructed_np - S2D_test_target).reshape(n_time, -1), axis=1)
relative_l2_error = norm_diff / (norm_true + 1e-10)
l2_dir_error = np.mean(relative_l2_error)

# R-squared
y_true_flat = S2D_test_target.flatten()
y_pred_flat = S2D_reconstructed_np.flatten()
ss_res = np.sum((y_true_flat - y_pred_flat) ** 2)
ss_tot = np.sum((y_true_flat - np.mean(y_true_flat)) ** 2)
r2_dir = 1 - (ss_res / ss_tot)

print("\n" + "="*60)
print("DIRECTIONAL COEFFICIENT MODEL EVALUATION RESULTS")
print("="*60)
print("WEIGHTED ENERGY-BASED ERROR:")
print(f"Directional model error:           {dir_error:.6f}")

print("\nL2 NORM ERROR:")
print(f"Directional L2 error:              {l2_dir_error:.6f}")

print("\nR-SQUARED ANALYSIS:")
print(f"Directional R²:                    {r2_dir:.6f} ({r2_dir*100:.2f}% variance explained)")

# Energy conservation
energy_conservation = np.abs(
    np.mean(np.sum(S2D_reconstructed_np, axis=(1,2))) - np.mean(np.sum(S2D_test_target, axis=(1,2)))
) / np.mean(np.sum(S2D_test_target, axis=(1,2)))

print(f"\nAdditional statistics:")
print(f"Test set size:                     {len(S2D_test_target)} samples")
print(f"Energy conservation error:         {energy_conservation:.6f}")

# Correlation coefficient
correlation = np.corrcoef(y_true_flat, y_pred_flat)[0, 1]
print(f"Pearson correlation:               {correlation:.6f}")

print(f"\nDIRECTIONAL MODEL SUMMARY:")
print(f"  Input: S1D + a1 + b1 + a2 + b2 → (batch, 30, 5)")
print(f"  Output: a3 + b3 + a4 + b4 + a5 + b5 → (batch, 30, 6)")
print(f"  Reconstruction: Full Fourier series (up to 5th harmonic)")
print(f"  Architecture: Simple MLP per frequency")
print(f"  Final Performance:")
print(f"    - Weighted Error: {dir_error:.6f}")
print(f"    - L2 Error: {l2_dir_error:.6f}")
print(f"    - R²: {r2_dir:.6f} ({r2_dir*100:.2f}% variance explained)")

print("\n✅ Directional coefficient model evaluation completed!")
print("="*60)
# Out:
# Evaluating directional coefficient model...
#
# ============================================================
# DIRECTIONAL COEFFICIENT MODEL EVALUATION RESULTS
# ============================================================
# WEIGHTED ENERGY-BASED ERROR:
# Directional model error:           0.452689
#
# L2 NORM ERROR:
# Directional L2 error:              0.453744
#
# R-SQUARED ANALYSIS:
# Directional R²:                    0.789722 (78.97% variance explained)
#
# Additional statistics:
# Test set size:                     1427 samples
# Energy conservation error:         0.000000
# Pearson correlation:               0.906217
#
# DIRECTIONAL MODEL SUMMARY:
#   Input: S1D + a1 + b1 + a2 + b2 → (batch, 30, 5)
#   Output: a3 + b3 + a4 + b4 + a5 + b5 → (batch, 30, 6)
#   Reconstruction: Full Fourier series (up to 5th harmonic)
#   Architecture: Simple MLP per frequency
#   Final Performance:
#     - Weighted Error: 0.452689
#     - L2 Error: 0.453744
#     - R²: 0.789722 (78.97% variance explained)
#
# ✅ Directional coefficient model evaluation completed!
# ============================================================

# %%
# Visualization: Compare true vs reconstructed spectra
print("Creating visualization...")

# Select 3 examples for visualization 
sample_indices = [0, len(S2D_test_target)//2, len(S2D_test_target)-1]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, idx in enumerate(sample_indices):
    # True spectrum (top row)
    true_spectrum = S2D_test_target[idx]
    pred_spectrum = S2D_reconstructed_np[idx]
    
    # Determine color scale
    vmax = max(true_spectrum.max(), pred_spectrum.max())
    
    # True spectrum
    im1 = axes[0, i].imshow(true_spectrum.T, aspect='auto', cmap='viridis', 
                           origin='lower', vmin=0, vmax=vmax)
    axes[0, i].set_title(f'True 2D Spectrum {idx+1}')
    axes[0, i].set_xlabel('Frequency Bin')
    axes[0, i].set_ylabel('Direction Bin')
    plt.colorbar(im1, ax=axes[0, i])
    
    # Predicted spectrum
    im2 = axes[1, i].imshow(pred_spectrum.T, aspect='auto', cmap='viridis',
                           origin='lower', vmin=0, vmax=vmax)
    axes[1, i].set_title(f'Reconstructed Spectrum {idx+1}')
    axes[1, i].set_xlabel('Frequency Bin')
    axes[1, i].set_ylabel('Direction Bin')
    plt.colorbar(im2, ax=axes[1, i])
    
    # Add error metrics as text
    sample_error = relative_l2_error[idx]
    axes[1, i].text(0.02, 0.98, f'L2 Error: {sample_error:.4f}', 
                    transform=axes[1, i].transAxes, fontsize=10,
                    verticalalignment='top', 
                    bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.suptitle(f'Directional Fourier Model Results (R² = {r2_dir:.4f})', fontsize=16)
plt.tight_layout()
plt.show()

# Scatter plot for overall performance
plt.figure(figsize=(8, 6))
n_points = min(10000, len(y_true_flat))
indices = np.random.choice(len(y_true_flat), n_points, replace=False)

plt.scatter(y_true_flat[indices], y_pred_flat[indices], alpha=0.5, s=1)
plt.plot([y_true_flat.min(), y_true_flat.max()], [y_true_flat.min(), y_true_flat.max()], 'r--', alpha=0.8)
plt.xlabel('True 2D Spectrum')
plt.ylabel('Predicted 2D Spectrum')
plt.title(f'Directional Fourier Model Performance\nR² = {r2_dir:.4f}')
plt.grid(True, alpha=0.3)
plt.show()

print("\n✅ Visualization completed!")
print(f"Model successfully predicts higher-order Fourier coefficients")
print(f"and reconstructs 2D spectra with R² = {r2_dir:.4f}")
# Out:
# Creating visualization...
# ✅ Visualization completed!
# Model successfully predicts higher-order Fourier coefficients
# and reconstructs 2D spectra with R² = 0.7897
